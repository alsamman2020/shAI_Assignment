# %% [markdown]
# # About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # Features
# - 'Id'
# - 'EmployeeName'
# - 'JobTitle'
# - 'BasePay'
# - 'OvertimePay'
# - 'OtherPay'
# - 'Benefits'
# - 'TotalPay' -> salary
# - 'TotalPayBenefits'
# - 'Year'
# - 'Notes'
# - 'Agency'
# - 'Status'

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %% [markdown]
# # Very Important Note
# There is no fixed or singular solution for this assignment, so if anything is not clear, please do what you understand and provide an explanation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('Salaries.csv')
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %% [markdown]
# # 1. Basic Data Exploration:

# %% [markdown]
# Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column

# %%
# Display basic information about the dataset
print("Number of rows and columns:", df.shape)

# Display data types of each column
print("\nData types of each column:")
print(df.dtypes)

# Check for missing values in each column
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Number of rows and columns: (148654, 13)
#
# Data types of each column:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object
#
# Missing values in each column:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# # 2. Descriptive Statistics:

# %% [markdown]
# Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.

# %%
# Calculate basic statistics for salary-related columns
salary_columns = ['BasePay', 'OvertimePay', 'OtherPay', 'Benefits', 'TotalPay', 'TotalPayBenefits']

for column in salary_columns:
    print(f"\nStatistics for {column}:")
    print(f"Mean: {df[column].mean()}")
    print(f"Median: {df[column].median()}")
    print(f"Mode: {df[column].mode().values[0]}")
    print(f"Minimum: {df[column].min()}")
    print(f"Maximum: {df[column].max()}")
    print(f"Range: {df[column].max() - df[column].min()}")
    print(f"Standard Deviation: {df[column].std()}")
# Out:
# Statistics for BasePay:
# Mean: 66325.4488404877
# Median: 65007.45
# Mode: 0.0
# Minimum: -166.01
# Maximum: 319275.01
# Range: 319441.02
# Standard Deviation: 42764.63549525887
#
# Statistics for OvertimePay:
# Mean: 5066.059886444667
# Median: 0.0
# Mode: 0.0
# Minimum: -0.01
# Maximum: 245131.88
# Range: 245131.89
# Standard Deviation: 11454.380558670258
#
# Statistics for OtherPay:
# Mean: 3648.767296804575
# Median: 811.27
# Mode: 0.0
# Minimum: -7058.59
# Maximum: 400184.25
# Range: 407242.84
# Standard Deviation: 8056.601865587466
#
# Statistics for Benefits:
# Mean: 25007.893150829852
# Median: 28628.62
# Mode: 0.0
# Minimum: -33.89
# Maximum: 96570.66
# Range: 96604.55
# Standard Deviation: 15402.215857867079
#
# Statistics for TotalPay:
# Mean: 74768.32197169267
# Median: 71426.60999999999
# Mode: 0.0
# Minimum: -618.13
# Maximum: 567595.43
# Range: 568213.56
# Standard Deviation: 50517.00527394987
#
# Statistics for TotalPayBenefits:
# Mean: 93692.55481056681
# ...

# %% [markdown]
# # 3. Data Cleaning:

# %% [markdown]
# Handle missing data by suitable method with explain why you use it

# %% [markdown]
# ## Dropping Missing Values:

# %% [markdown]
# This method removes rows containing any missing values. It's a straightforward approach, because the missing value we have not important."

# %%
df_cleaned = df.dropna()

# %% [markdown]
# # 4. Basic Data Visualization:

# %% [markdown]
# Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.

# %% [markdown]
# ## Histogram for Salary Distribution:

# %%
# Histogram for TotalPay
plt.figure(figsize=(10, 6))
plt.hist(df['TotalPay'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Salaries')
plt.xlabel('Total Pay')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Pie Chart for Proportion of Employees in Different Departments over the years:

# %%
# Pie chart for distribution over the years
year_counts = df['Year'].value_counts().sort_index()
plt.figure(figsize=(8, 8))
plt.pie(year_counts, labels=year_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightgreen', 'lightblue'])
plt.title('Distribution of Employees Over the Years')
plt.show()

# %% [markdown]
# # 5. Grouped Analysis:

# %% [markdown]
# Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.

# %%
# Group the data by 'JobTitle' and calculate summary statistics for each group
grouped_data = df.groupby('JobTitle')['TotalPay'].agg(['count', 'mean', 'median', 'min', 'max']).sort_values(by='mean', ascending=False)

# Display the grouped data
print(grouped_data)
# Out:
#                                                 count           mean  \
# JobTitle
# GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY      2  399211.275000
# Chief Investment Officer                            1  339653.700000
# Chief of Police                                     3  329183.646667
# Chief, Fire Department                              3  325971.683333
# DEPUTY DIRECTOR OF INVESTMENTS                      1  307899.460000
# ...                                               ...            ...
# Commissioner 16.700c, No Pay                       50      25.760000
# IS Technician Assistant                             1       0.000000
# Not provided                                        4       0.000000
# Public Safety Comm Tech                             1       0.000000
# Drug Court Coordinator                              1       0.000000
#
#                                                     median        min  \
# JobTitle
# ...

# %% [markdown]
# # 6. Simple Correlation Analysis:

# %% [markdown]
# Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.

# %%
# Calculate the correlation coefficient
correlation = df['TotalPay'].corr(df['BasePay'])
print(f"Correlation between TotalPay and BasePay: {correlation}")

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['BasePay'], df['TotalPay'], alpha=0.5)
plt.title('Scatter Plot: TotalPay vs BasePay')
plt.xlabel('BasePay')
plt.ylabel('TotalPay')
plt.show()
# Out:
# Correlation between TotalPay and BasePay: 0.9544936474296029

# %% [markdown]
# # 7. Summary of Insights:

# %% [markdown]
# Write a brief report summarizing the findings and insights from the analyses.

# %% [markdown]
# ### Data Overview:
# The dataset provides information about employees in an organization, including their names, job titles, salaries ('TotalPay'), and additional details such as 'BasePay', 'OvertimePay', 'OtherPay', and 'Benefits'. The analysis focused on understanding the distribution of salaries, exploring employee demographics, and identifying potential correlations.
#
# **Descriptive Statistics:**
# - The dataset contains information for multiple years.
# - Salary distribution exhibits variations, with some employees having high 'TotalPay' values.
# - The 'JobTitle' column reveals the diverse roles within the organization.
#
# **Employee Distribution Over the Years:**
# - A bar chart illustrates the distribution of employees over the years. The organization appears to have experienced fluctuations in the number of employees during different years.
#
# **Grouped Analysis by Job Title:**
# - Grouping the data by 'JobTitle' allowed us to compare average salaries across different roles.
# - Summary statistics (count, mean, median, min, max) for 'TotalPay' were calculated for each job title.
#
# **Correlation Analysis:**
# - The correlation between 'TotalPay' and another numerical column ('BasePay') was examined.
# - A scatter plot visually represents the relationship between these two variables.
#
# ### Insights:
# 1. **Salary Distribution:** The salary distribution is varied, with some employees earning significantly higher than others. Understanding the factors contributing to these variations would be crucial for HR and management decisions.
#
# 2. **Employee Trends Over the Years:** Fluctuations in the number of employees over the years may suggest organizational changes or external factors influencing workforce dynamics.
#
# 3. **Job Title Analysis:** Analyzing salaries by job titles provides insights into the organization's compensation structure. It can guide decisions related to salary adjustments and recruitment strategies.
#
# 4. **Correlation between 'TotalPay' and 'BasePay':** The scatter plot suggests a positive correlation between 'TotalPay' and 'BasePay'. Further analysis could delve into the factors contributing to this correlation and whether it holds across different job roles or departments.
#
# ### Recommendations:
# 1. **Further Analysis:** Conduct more in-depth analyses to understand the factors influencing salary variations and identify any anomalies or outliers.
#
# 2. **Job-Specific Analysis:** Explore correlations and trends within specific job titles or departments to provide targeted insights.
#
# 3. **Regular Data Updates:** If applicable, consider regular updates to the dataset for ongoing analysis and monitoring of organizational trends.
#
# This brief report summarizes key findings and highlights potential areas for further investigation. It serves as a foundation for more detailed analyses and data-driven decision-making within the organization.
